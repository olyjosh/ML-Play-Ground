# %%
import pandas as pd

# %%
df = pd.read_csv('DataScience_salaries_2024.csv');
df
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %%
df.employment_type.count_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mn/90h80_l15db210x8sxs24sg80000gn/T/ipykernel_76340/1169947355.py in ?()
# ----> 1 df.employment_type.count_values()
#
# /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'count_values'

# %%
df['employment_type'] = df['employment_type'].apply(lambda x: 1 if x == 'FT' else 0)
df
# Out:
#        work_year experience_level  employment_type  \
# 0           2021               MI                0
# 1           2021               MI                0
# 2           2020               MI                0
# 3           2021               MI                0
# 4           2022               SE                0
# ...          ...              ...              ...
# 14833       2022               MI                0
# 14834       2020               EX                0
# 14835       2021               EN                0
# 14836       2022               EN                0
# 14837       2020               EN                0
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...
